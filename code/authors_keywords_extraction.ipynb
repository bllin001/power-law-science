# %%
# Importing necessary libraries
import pandas as pd
from collections import Counter

# %%
data = pd.read_csv('../data/papers.csv')
data
# Out:
#                                                 Authors  \
# 0     Tao D.; Zhang R.; Xu J.; Zheng L.; Zhang G.; Z...
# 1     Promkhambut A.; Yokying P.; Woods K.; Fisher M...
# 2     Rasekhi S.; Mofidi-Chelan M.; Skataric G.; Vär...
# 3                            Oktavianus J.; Davidson B.
# 4      Junger L.; Davids P.; Stöglehner G.; Hartmann T.
# ...                                                 ...
# 2622                                          Gillen M.
# 2623                                Pelling M.; High C.
# 2624                            Degg M.R.; Chester D.K.
# 2625                                            Pugh J.
# 2626                                      Neil Adger W.
#
#                                       Author full names  \
# 0     Tao, Dawei (36679177300); Zhang, Ruijin (57787...
# 1     Promkhambut, Arunee (36551471600); Yokying, Ph...
# 2     Rasekhi, Sareh (58654635100); Mofidi-Chelan, M...
# 3     Oktavianus, Jeffry (57219595487); Davidson, Br...
# 4     Junger, L. (57226157526); Davids, P. (57208921...
# ...                                                 ...
# 2622                          Gillen, Mike (8861678000)
# 2623  Pelling, Mark (7003350514); High, Chris (16506...
# 2624  Degg, Martin R. (55200929600); Chester, David ...
# 2625                       Pugh, Jonathan (55349800400)
# 2626                        Neil Adger, W. (7004013611)
#
#                                            Author(s) ID  \
# 0     36679177300; 57787223400; 57196735064; 5852592...
# 1     36551471600; 57194175299; 56427044400; 5643033...
# 2     58654635100; 57212586859; 57206668275; 1483196...
# 3                              57219595487; 57226274860
# 4     57226157526; 57208921403; 57211128670; 3579539...
# ...                                                 ...
# 2622                                         8861678000
# 2623                            7003350514; 16506507200
# 2624                            55200929600; 7004271121
# 2625                                        55349800400
# 2626                                         7004013611
#
#                                                   Title  Year  \
# 0     Understanding the nature of early agriculture ...  2023
# 1     Rethinking agrarian transition in Southeast As...  2023
# 2     Sustainability of the local stakeholder networ...  2023
# 3     Countering terrorism on social media: An analy...  2023
# 4     Multidimensional resilience - flood recovery o...  2023
# ...                                                 ...   ...
# 2622  Urban governance and vulnerability: Exploring ...  2005
# 2623  Understanding adaptation: What can social capi...  2005
# 2624  Seismic and volcanic hazards in Peru: Changing...  2005
# 2625  Environmental planning in Barbados: A confiden...  2005
# 2626  Social vulnerability to climate change and ext...  1999
#
#                                           Source title Volume Issue Art. No.  \
# 0           Journal of Archaeological Science: Reports     51   NaN   104162
# 1                                    World Development    169   NaN   106309
# 2                                    Applied Geography    161   NaN   103093
# 3                         Communication and the Public      8     4      NaN
# 4     International Journal of Disaster Risk Reduction     96   NaN   103993
# ...                                                ...    ...   ...      ...
# 2622                                            Cities     22     1      NaN
# 2623                       Global Environmental Change     15     4      NaN
# 2624                              Geographical Journal    171     2      NaN
# 2625                           Southeastern Geographer     45     2      NaN
# 2626                                 World Development     27     2      NaN
#
#      Page start  ... ISBN  CODEN  PubMed ID Language of Original Document  \
# 0           NaN  ...  NaN    NaN        NaN                       English
# 1           NaN  ...  NaN    NaN        NaN                       English
# 2           NaN  ...  NaN    NaN        NaN                       English
# 3           308  ...  NaN    NaN        NaN                       English
# 4           NaN  ...  NaN    NaN        NaN                       English
# ...         ...  ...  ...    ...        ...                           ...
# 2622         55  ...  NaN    NaN        NaN                       English
# 2623        308  ...  NaN  GECHE        NaN                       English
# 2624        125  ...  NaN  GGJOA        NaN                       English
# 2625        192  ...  NaN    NaN        NaN                       English
# 2626        249  ...  NaN    NaN        NaN                       English
#
#            Abbreviated Source Title Document Type Publication Stage  \
# 0             J.Archaeol. Sci. Rep.       Article             Final
# 1                        World Dev.       Article             Final
# 2                      Appl. Geogr.       Article             Final
# 3      Communication and the Public       Article             Final
# 4     Int. J. Disaster Risk Reduct.       Article             Final
# ...                             ...           ...               ...
# 2622                         Cities       Article             Final
# 2623         Global Environ. Change       Article             Final
# 2624                      Geogr. J.       Article             Final
# 2625              Southeast. Geogr.       Article             Final
# 2626                     World Dev.       Article             Final
#
#                                    Open Access  Source                 EID
# 0                                          NaN  Scopus  2-s2.0-85166970356
# 1     All Open Access; Hybrid Gold Open Access  Scopus  2-s2.0-85161705867
# 2                                          NaN  Scopus  2-s2.0-85174464410
# 3                                          NaN  Scopus  2-s2.0-85166207236
# 4     All Open Access; Hybrid Gold Open Access  Scopus  2-s2.0-85170416926
# ...                                        ...     ...                 ...
# 2622                                       NaN  Scopus  2-s2.0-27444442266
# 2623                                       NaN  Scopus  2-s2.0-27744523506
# 2624                                       NaN  Scopus  2-s2.0-22144457915
# 2625                                       NaN  Scopus  2-s2.0-27244449338
# 2626                                       NaN  Scopus   2-s2.0-0344655681
#
# [2627 rows x 46 columns]

# %%
# Use only 'Author Keywords' and convert to lowercase
data['Author Keywords'] = data['Author Keywords'].str.lower()
data[['Title', 'Author Keywords']].head()
# Out:
#                                                Title  \
# 0  Understanding the nature of early agriculture ...
# 1  Rethinking agrarian transition in Southeast As...
# 2  Sustainability of the local stakeholder networ...
# 3  Countering terrorism on social media: An analy...
# 4  Multidimensional resilience - flood recovery o...
#
#                                      Author Keywords
# 0  agricultural sustainability; archaeobotany; ce...
# 1  agrarian transition; rice; smallholder persist...
# 2  cooperation; social capital; social resilience...
# 3  collective actions; counter-terrorism; framing...
# 4  financial resilience; flood risk management; l...

# %%
# Handle NaN values and ensure splitting of strings only
def split_keywords(keywords):
    if pd.notna(keywords):
        return [keyword.strip() for keyword in keywords.split(';')]
    else:
        return []

# Split the 'Author Keywords' into a list of keywords
data['Keyword List'] = data['Author Keywords'].apply(split_keywords)
data[['Title', 'Author Keywords', 'Keyword List']].head()
# Out:
#                                                Title  \
# 0  Understanding the nature of early agriculture ...
# 1  Rethinking agrarian transition in Southeast As...
# 2  Sustainability of the local stakeholder networ...
# 3  Countering terrorism on social media: An analy...
# 4  Multidimensional resilience - flood recovery o...
#
#                                      Author Keywords  \
# 0  agricultural sustainability; archaeobotany; ce...
# 1  agrarian transition; rice; smallholder persist...
# 2  cooperation; social capital; social resilience...
# 3  collective actions; counter-terrorism; framing...
# 4  financial resilience; flood risk management; l...
#
#                                         Keyword List
# 0  [agricultural sustainability, archaeobotany, c...
# 1  [agrarian transition, rice, smallholder persis...
# 2  [cooperation, social capital, social resilienc...
# 3  [collective actions, counter-terrorism, framin...
# 4  [financial resilience, flood risk management, ...

# %%
# Create a unique list of all keywords
unique_keywords = set()
for keywords in data['Keyword List']:
    unique_keywords.update(keywords)

print(f'Total number of unique concepts: {len(unique_keywords)}')
# Out:
# Total number of unique concepts: 6847

# %%
# Count the frequency of each keyword across all rows
total_keyword_count = Counter()
for keywords in data['Keyword List']:
    total_keyword_count.update(keywords)
    
total_keyword_count.most_common(10)
# Out:
# [('resilience', 430),
#  ('climate change', 183),
#  ('vulnerability', 176),
#  ('social resilience', 112),
#  ('adaptation', 110),
#  ('community resilience', 83),
#  ('covid-19', 72),
#  ('adaptive capacity', 68),
#  ('sustainability', 66),
#  ('social capital', 64)]

# %%
# Convert the Counter object to a dataframe
keywords_df = pd.DataFrame(total_keyword_count.items(), columns=['Concepts', 'Total'])
keywords_df = keywords_df.sort_values(by='Total', ascending=False)
keywords_df = keywords_df.reset_index(drop=True)
keywords_df = keywords_df[(keywords_df['Concepts'] != '')]
keywords_df.head(10)
# Out:
#                Concepts  Total
# 0            resilience    430
# 1        climate change    183
# 2         vulnerability    176
# 3     social resilience    112
# 4            adaptation    110
# 5  community resilience     83
# 6              covid-19     72
# 7     adaptive capacity     68
# 8        sustainability     66
# 9        social capital     64

# %%
# Save the dataframe to a CSV file
keywords_df.to_csv('../data/authors_keyword_frequency.csv', index=False)

# %%
# Plot top 10 keywords
import matplotlib.pyplot as plt
import seaborn as sns
top_10 = keywords_df.head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x='Total', y='Concepts', data=top_10, palette='viridis')
plt.title('Top 10 Most Frequent Keywords')
plt.xlabel('Frequency')
plt.ylabel('Index Keywords')
plt.show()
# Out:
# /var/folders/vt/9xf6xhpx3b16kyttfwqfh3kr0000gr/T/ipykernel_88304/1481628820.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Total', y='Concepts', data=top_10, palette='viridis')
